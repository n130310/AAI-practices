# %% [markdown]
# ФИО

# %%
print('Насртдинова Вероника Альфисовна')
# Out:
# Насртдинова Вероника Альфисовна

# %% [markdown]
# **Во всей практике нельзя применять библиотеки предоставляющие готовые решения!**

# %% [markdown]
# # **Задача 1.**

# %% [markdown]
# Типы данных Напишите программу на Python, которая принимает список чисел в качестве входных данных от пользователя, а затем выводит сумму, среднее значение и максимальное значение из списка.
#
# ***Нельзя использовать: len(), min(), max(), average(), sum()***
#
# Ввод:
# ```
# 1 2 3 4 5 6 7
# ```
# Вывод:
#
# ```
# Сумма чисел: 28
# Среднее арифм.: 4.0
# Максимальное значение: 7
# ```

# %%
operation = input('Введите список чисел: ');

summa = 0;
for number in operation.split(' '):
  summa = summa + int(number);
print(summa);

max = 0;
for number in operation.split(' '):
  if int(number) >= max :
    max = int(number);
print(max);

mean = 0;
count = 0;
for number in operation.split(' '):
  count = count + 1;
mean = summa / count;
print(mean)
# Out:
# Введите список чисел: 2 3 2 3
# 10
# 3
# 2.5

# %% [markdown]
# # **Задача 2.**

# %% [markdown]
# Напишите программу на Python, которая принимает список слов в качестве входных данных от пользователя, а затем распечатывает список в обратном порядке.
#
# Ввод:
#
# ```
# апельсин мандарин яблоко
# ```
#
# Вывод:
#
# ```
# яблоко мандарин апельсин
# ```

# %%
text = input('Введите список слов: ');
reverse = text.split(' ');
reversed = reverse[::-1];
print(' '.join(reversed))
# Out:
# Введите список слов: пощади меня шайтан машина
# машина шайтан меня пощади

# %% [markdown]
# # **Задача 3**

# %% [markdown]
# Простой чат-бот
# Создайте простого чат-бота, который отвечает на основные запросы пользователей. Программа должна использовать условные выражения для определения намерений пользователя и последующего соответствующего ответа.
#
# Чат бот может:
#
# - помогать складывать числа
# - подсказывать фильм, музыку и тд (из заранее созданного списка)
# - создавать список дел (а также выводить его, обновлять, очищать)
#
# Интерфейс чат-бота на ваше усмотрение, это могут быть как заранее определенные команды, так и к примеру вызов команды по номеру
#
# *Реализовать без использования функций*
#
# Пример:
#
# Ввод:
#
# ```
# Олег, какую мызыку посоветуешь?
# ```
#
# Вывод:
#
# ```
# Я бы посоветовал вам: Led Zeppelin Stairway to Heaven
# ```

# %%
import random;
movies = ['"Джон Уик"', '"Бойцовский клуб"', '"Тачки"', '"Пятый элемент"', '"Джей и молчаливый Боб"'];
music = ['AC/DC - Highway to Hell', 'Queen - Bohemian Rhapsody', 'Kiss - I Was Made For Lovin You', 'Nirvana - Smells Like Teen Spirit ', 'Gorillaz - DARE'];
todo = ['Прибраться', 'Приготовить обед', 'Лечь спать'];
n = random.randint(0, 4);

command = int(input('Введите запрос! '));

if command == 1 :
  choice = input('Введите числа для сложения: ');
  summa = 0;
  for number in choice.split(' '):
   summa = summa + int(number);
  print(summa);
if command == 2 :
  choice = input('Фильм или музыка? ');
  if (choice == 'фильм') or (choice == 'Фильм') :
      print('Совет дня! ', movies[n]);
  if (choice == 'музыка') or (choice == 'Музыка') :
      print('Предлагаю сегодня послушать ', music[n]);
if command == 3 :
  choice = input('Что вы хотите сделать со своим списком дел? ');
  if (choice == 'Показать') or (choice == 'показать') :
    for item in todo:
     print(item);
  if (choice == 'добавить') or (choice == 'Добавить') :
    todo.append(input('Что вы хотите добавить? '));
    print('Ваш новый список!');
    for item in todo:
     print(item);
  if (choice == 'Очистить') or (choice == 'очистить') or (choice == 'удалить') :
    todo = ' ';
    print('Ваш список был очищен!');
else :
  print('Неправильно введенная команда!')
# Out:
# Введите запрос! 3
# Что вы хотите сделать со своим списком дел? очистить
# Ваш список был очищен!

# %% [markdown]
# # **Задача 4.**

# %% [markdown]
# Камень, ножницы, бумага
#
# Создайте игру в Камень, ножницы, бумагу, в которой пользователь может играть против компьютера. Программа должна запросить выбор пользователя, а затем сгенерировать выбор компьютера. Затем программа должна определить победителя на основе правил игры.
#
# **Этап 1:**
#
# Определение победителя
#
# **Этап 2:**
#
# Игра до 3 побед
#
#
# Ввод для "Этап 1":
#
# ```
# Камень
# ```
#
# Вывод:
#
# ```
# Компьютер: Ножницы
# Игрок: Камень
# Победа: Игрок
# ```

# %%
import random;

player = input('Введите ваш ход! ');


n = random.randint(1, 3);
if n == 1 :
  ai = "Камень";
elif n == 2 :
  ai = 'Ножницы';
else :
  ai = "Бумага";

if (player == 'Камень' and ai == 'Ножницы') or (player == 'Ножницы' and ai == 'Бумага') or  (player == 'Бумага' and ai == 'Камень'):
  result = 'Игрок';
elif player == ai :
  result = 'Ничья';
else :
  result = 'Компьютер';

print('Компьютер: ', ai);
print('Игрок: ', player);
print('Победа: ', result)


'''
Этап 2!
import random;

result = 0;
i = 0;
while i < 3 :
  player = input('Введите ваш ход! ');
  n = random.randint(1, 3);
  if n == 1 :
    ai = "Камень";
  elif n == 2 :
    ai = 'Ножницы';
  else :
    ai = "Бумага";

  if (player == 'Камень' and ai == 'Ножницы') or (player == 'Ножницы' and ai == 'Бумага') or  (player == 'Бумага' and ai == 'Камень'):
    result = result + 1;
  elif player == ai :
    result = result;
  else :
    result = result;
  i = i + 1;
  print('Компьютер: ', ai);
  print('Игрок: ', player);
  print('Победа: ', result)


if result >= 2 :
  print('Вы победили!');
else :
  print('Вы проиграли!');
'''
# Out:
# Введите ваш ход! Камень
# Компьютер:  Камень
# Игрок:  Камень
# Победа:  Ничья
# '\nimport random;\n \nresult = 0;\ni = 0;\nwhile i < 3 :\n  player = input(\'Введите ваш ход! \');\n  n = random.randint(1, 3);\n  if n == 1 :\n    ai = "Камень";\n  elif n == 2 :\n    ai = \'Ножницы\';\n  else :\n    ai = "Бумага";\n\n  if (player == \'Камень\' and ai == \'Ножницы\') or (player == \'Ножницы\' and ai == \'Бумага\') or  (player == \'Бумага\' and ai == \'Камень\'):\n    result = result + 1;\n  elif player == ai :\n    result = result;\n  else :\n    result = result;\n  i = i + 1;\n  print(\'Компьютер: \', ai);\n  print(\'Игрок: \', player);\n  print(\'Победа: \', result)\n\n\nif result >= 2 :\n  print(\'Вы победили!\');\nelse :\n  print(\'Вы проиграли!\');\n'

# %% [markdown]
# # **Задача 5.**

# %% [markdown]
# Создайте игру "Палач" или "Виселица", в которой пользователь должен угадать слово, предлагая буквы. Программа должна выбрать случайное слово, а затем разрешить пользователю угадывать буквы. После каждого угадывания программа должна сообщать пользователю, есть ли в слове буква или нет.
#
# **Этап 1**
# Создать саму игру (игра должна иметь привлекательный интерфейс, соотвесвующий классической висилице)
#
# **Этап 2:**
# Ввести подсчет количества очков и ограничения на попытки
#
# **Этап 3:** Добавить возможность сразу угадать слово

# %%
import random

hanging = ['____________ ', '|           |    повесился в 1.0', '|           |', '|          ', '|          ', '|           ', '|              O', '|             -|-', '|___________П_ Л ', ''];
for i in hanging :
 print(i);

score = input('Начать игру? ');
#чистить пространство работает только в программе, придумать как сделать здесь

words = ['машина', 'картофель', 'пирог', 'десять', 'некрасиво', 'шахматы', 'рандом', 'кофе', 'эпсилон', 'комета', 'слово'];
random_word = list(random.choice(words));
hiddenword = [];
for number in random_word:
  hiddenword.append('█')
hanging[9] = ''.join(hiddenword);
print(hanging[9]);
fails = 0;

while (''.join(hiddenword)) != (''.join(random_word)) and (fail != 5):
  guess = input('Введите букву! ');
  if

#скоро тут будет на одного повешанного больше
# Out:
# ____________
# |           |    повесился в 1.0
# |           |
# |
# |
# |
# |              O
# |             -|-
# |___________П_ Л
#
# Начать игру? lf
# ███████
# Введи букву! а

# %% [markdown]
# # **Дополнительно: Задача 6.**

# %% [markdown]
# **Цифра на определенном месте:**
#
# Последовательно записан натуральный ряд чисел.
#
# Какая цифра стоит в N позиции
#
#
# Вввод:
#
# ```
# Введите номер позиции: 1234567890
# ```
#
# Вывод:
#
# ```
# 8
# ```

# %%
n = int(input('Введите номер позиции числа: '));

numbers = list(range(1, n+1));
numbers = ''.join(map(str, numbers));
#print(numbers);
print(numbers[n-1])
# Out:
# Введите номер позиции числа: 543
# 7
